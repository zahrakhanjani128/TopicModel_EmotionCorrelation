# %% [markdown]
# #### Importing the Libraries

# %%
from math import sqrt
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import plotly.express as px
import plotly.graph_objects as go
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

# %%
df = pd.read_csv('IS733_dataset_emo_label_en.csv')

# %% [markdown]
# ### LDA Method:

# %% [markdown]
# We have deleted stopwords before, now we are going to do tokenizing for LDA on df:

# %%
import spacy
spacy.load("en_core_web_sm")
from spacy.lang.en import English
parser = English()
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

# %% [markdown]
# We use NLTK’s Wordnet to find the meanings of words, synonyms, antonyms, and more. In addition, we use WordNetLemmatizer to get the root word.

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet as wn
def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
from nltk.stem.wordnet import WordNetLemmatizer
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# Open up our data, read line by line, for each line, prepare text for LDA, then add to a list.
#
# Now we can see how our text data are converted:

# %%
def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
df_lda2 = df["Text"]

# %%
df_lda2.to_csv(r'IS733_dataset_LDA_input.csv')

# %%
import random
text_data = []
with open('IS733_dataset_LDA_input.csv') as f:
    for line in f:
        tokens = prepare_text_for_lda(line)
        text_data.append(tokens)
print(text_data)
# Out:
# [[], [], [], ['window'], ['fill', 'form'], ['last-', 'first', 'jones'], [], ['jones'], ['strange', 'figure', 'fill', 'wrong', 'section'], [], ["what's", 'apply'], ['apply', 'another'], ['another'], ['suppose', 'three', 'form', 'story', 'suppose', 'three', 'form', 'really', 'another'], [], ['right'], ['second'], ['really', 'simple', 'problem', 'maybe', 'should--'], [], ['waiting', 'another'], ['passport'], ['passport'], ['birth', 'certificate'], ['though', 'somewhere'], ['expect'], ['probably', 'another', 'birth', 'certificate'], ['probably'], ['helpful'], [], [], [], [], ['understand', 'driver', 'license', 'california'], ['breathing'], ['california'], [], ['form', 'already'], ['driver', 'license'], ['driver', 'license'], ['suppose', 'california'], ['fill', 'questions--'], ['raise', 'voice'], ['already', 'answer', 'question'], ['child'], [], ['working', 'live', 'california'], ['make', 'acting', 'child'], ['california', 'whole--'], ['maybe', 'never', 'd.m.v.', 'maybe', 'number', 'different'], ['getting'], ['voice', 'yelling', 'match'], ['perfectly'], ['yelling', 'match', 'right'], ['yelling', 'match', 'either'], [], ['enough', 'people'], ['people', 'suppose', 'ridiculous', 'manager', 'someone'], [], [], [], ['going', 'thank', 'problem', 'going'], ['talking'], ["'cause", 'obviously', 'talking', 'yelling', 'berating', 'telling', 'form', 'right'], [], ['honey', 'going', 'christmas', 'shame', 'going', 'picture'], [], [], [], ['happening'], [], ['letter'], [], ['first', 'thing', 'tomorrow', 'morning'], ['kid'], [], ['understand', 'underst--'], [], [], ['least', 'years'], ['guess'], ['national', 'guard', 'guess', 'really', 'spread', 'everyone', 'whole', 'company', 'going'], ['breathing'], [], ['believe'], ['leave', 'tomorrow'], ['breathing'], ['shipping'], ['shock', 'actually'], [], [], ['birthday', 'party'], ['guess', 'going', 'without'], ['listen', 'going', 'though', 'right'], ['going'], ['worry'], ['going'], [], ['really', 'group'], ['going'], ['going'], ['promise', 'going', 'picture'], ['always', 'always'], [], ['though'], ['something', 'could'], ['could'], [], ['build', 'bunker', 'never'], ['really'], ['laughter'], ['scare'], [], ['letter', 'every', 'single'], [], [], [], ['crazy', 'thing', 'happen'], [], ['offer', 'fifty', 'thousand', 'dollar', 'marry'], ['breathing'], [], [], ['citizen', 'want'], [], ['citizen', 'want', 'going', 'fifty', 'thousand', 'dollar', 'marry', 'married', 'years'], ['need', 'marry'], ['incredible', 'awesome', 'maybe', 'citizenship'], ['twenty', 'thousand', 'dollar', 'nothing', 'awesome'], ['actually', 'england', 'think', 'spoke', 'english', 'accent'], [], ['laughter'], ['fifty', 'thousand', 'dollar', 'fifty', 'thousand', 'dollar', 'friend', 'friend'], ['party', 'unattached'], ['believe', 'fifty', 'thousand', 'dollar', 'totally', 'fifty', 'thousand', 'dollar', 'thing', 'illegal', 'could', 'probably', 'catch'], ['unbelievable'], ['know', 'people', 'just-', 'really', 'actually', "'cause", 'engagement', 'party', 'friend'], [], ['really', 'going', 'married', 'whole', 'thing'], ['laughter'], ['could', 'could', 'money'], ['think', 'should-'], ['apartment', 'together', 'hundred', 'buck', 'month', 'something'], [], ['account', 'stuff'], [], [], ['lucked'], ['wedding'], ['colors', 'blush', 'beige'], ['something', 'something', 'something', 'laughter', 'wonder', 'going', 'front', 'think', 'though', 'think', 'going', 'track', 'money', 'something'], ['laughter'], [], ['hardcore'], [], ['married', 'party'], ['excite', 'wedding', 'beach'], ['like-', 'wedding', 'beach', 'would'], ['night'], ['honeymoon', 'tropical', 'though', 'bahamas-', 'tahiti', 'something', 'beach', 'drink'], ['absolutely', 'absolutely'], ['excite', 'bring', 'friend'], ['totally', 'wealthy', 'royalty-', 'something', '--whatever', 'remove', 'something'], ['garbage', 'load', 'fifty', 'thousand', 'dollar', 'incredible'], ['incredible'], ['going', 'marry', 'blood', 'laughter'], ['lucky', 'lucky', 'lucky'], [], ['totally'], [], [], ['check', 'really', 'sof ...

# %%
text_data
# Out:
# [[],
#  [],
#  [],
#  ['window'],
#  ['fill', 'form'],
#  ['last-', 'first', 'jones'],
#  [],
#  ['jones'],
#  ['strange', 'figure', 'fill', 'wrong', 'section'],
#  [],
#  ["what's", 'apply'],
#  ['apply', 'another'],
#  ['another'],
#  ['suppose',
#   'three',
#   'form',
#   'story',
#   'suppose',
#   'three',
#   'form',
#   'really',
#   'another'],
#  [],
#  ['right'],
#  ['second'],
#  ['really', 'simple', 'problem', 'maybe', 'should--'],
#  [],
#  ['waiting', 'another'],
#  ['passport'],
#  ['passport'],
#  ['birth', 'certificate'],
#  ['though', 'somewhere'],
#  ['expect'],
#  ['probably', 'another', 'birth', 'certificate'],
#  ['probably'],
#  ['helpful'],
#  [],
#  [],
#  [],
#  [],
#  ['understand', 'driver', 'license', 'california'],
#  ['breathing'],
#  ['california'],
#  [],
#  ['form', 'already'],
#  ['driver', 'license'],
#  ['driver', 'license'],
#  ['suppose', 'california'],
#  ['fill', 'questions--'],
#  ['raise', 'voice'],
#  ['already', 'answer', 'question'],
#  ['child'],
#  [],
#  ['working', 'live', 'california'],
#  ['make', 'acting', 'child'],
#  ['california', 'whole--'],
#  ['maybe', 'never', 'd.m.v.', 'maybe', 'number', 'different'],
#  ['getting'],
#  ['voice', 'yelling', 'match'],
#  ['perfectly'],
#  ['yelling', 'match', 'right'],
#  ['yelling', 'match', 'either'],
#  [],
#  ['enough', 'people'],
#  ['people', 'suppose', 'ridiculous', 'manager', 'someone'],
#  [],
#  [],
#  [],
#  ['going', 'thank', 'problem', 'going'],
#  ['talking'],
#  ["'cause",
#   'obviously',
#   'talking',
#   'yelling',
#   'berating',
#   'telling',
#   'form',
#   'right'],
#  [],
#  ['honey', 'going', 'christmas', 'shame', 'going', 'picture'],
#  [],
#  [],
#  [],
#  ['happening'],
#  [],
#  ['letter'],
#  [],
#  ['first', 'thing', 'tomorrow', 'morning'],
#  ['kid'],
#  [],
#  ['understand', 'underst--'],
#  [],
#  [],
#  ['least', 'years'],
#  ['guess'],
#  ['national',
#   'guard',
#   'guess',
#   'really',
#   'spread',
#   'everyone',
#   'whole',
#   'company',
#   'going'],
#  ['breathing'],
#  [],
#  ['believe'],
#  ['leave', 'tomorrow'],
#  ['breathing'],
#  ['shipping'],
#  ['shock', 'actually'],
#  [],
#  [],
#  ['birthday', 'party'],
#  ['guess', 'going', 'without'],
#  ['listen', 'going', 'though', 'right'],
#  ['going'],
#  ['worry'],
#  ['going'],
#  [],
#  ['really', 'group'],
#  ['going'],
#  ['going'],
#  ['promise', 'going', 'picture'],
#  ['always', 'always'],
#  [],
#  ['though'],
#  ['something', 'could'],
#  ['could'],
#  [],
#  ['build', 'bunker', 'never'],
#  ['really'],
#  ['laughter'],
#  ['scare'],
#  [],
#  ['letter', 'every', 'single'],
#  [],
#  [],
#  [],
#  ['crazy', 'thing', 'happen'],
#  [],
#  ['offer', 'fifty', 'thousand', 'dollar', 'marry'],
#  ['breathing'],
#  [],
#  [],
#  ['citizen', 'want'],
#  [],
#  ['citizen',
#   'want',
#   'going',
#   'fifty',
#   'thousand',
#   'dollar',
#   'marry',
#   'married',
#   'years'],
#  ['need', 'marry'],
#  ['incredible', 'awesome', 'maybe', 'citizenship'],
#  ['twenty', 'thousand', 'dollar', 'nothing', 'awesome'],
#  ['actually', 'england', 'think', 'spoke', 'english', 'accent'],
#  [],
#  ['laughter'],
#  ['fifty',
#   'thousand',
#   'dollar',
#   'fifty',
#   'thousand',
#   'dollar',
#   'friend',
#   'friend'],
#  ['party', 'unattached'],
#  ['believe',
#   'fifty',
#   'thousand',
#   'dollar',
#   'totally',
#   'fifty',
#   'thousand',
#   'dollar',
#   'thing',
#   'illegal',
#   'could',
#   'probably',
#   'catch'],
#  ['unbelievable'],
#  ['know',
#   'people',
#   'just-',
#   'really',
#   'actually',
#   "'cause",
#   'engagement',
#   'party',
#   'friend'],
#  [],
#  ['really', 'going', 'married', 'whole', 'thing'],
#  ['laughter'],
#  ['could', 'could', 'money'],
#  ['think', 'should-'],
#  ['apartment', 'together', 'hundred', 'buck', 'month', 'something'],
#  [],
#  ['account', 'stuff'],
#  [],
#  [],
#  ['lucked'],
#  ['wedding'],
#  ['colors', 'blush', 'beige'],
#  ['something',
#   'something',
#   'something',
#   'laughter',
#   'wonder',
#   'going',
#   'front',
#   'think',
#   'though',
#   'think',
#   'going',
#   'track',
#   'money',
#   'something'],
#  ['laughter'],
#  [],
#  ['hardcore'],
#  [],
#  ['married', 'party'],
#  ['excite', 'wedding', 'beach'],
#  ['like-', 'wedding', 'beach', 'would'],
#  ['night'],
#  ['honeymoon',
#   'tropical',
#   'though',
#   'bahamas-',
#   'tahiti',
#   'something',
#   'beach',
#   'drink'],
#  ['absolutely', 'absolutely'],
#  ['excite', 'bring', 'friend'],
#  ['totally',
#   'wealthy',
#   'royalty-',
#   'something',
#   '--whatever',
#   'remove',
#   'something'],
#  ['garbage', 'load', 'fifty', 'thousand', 'dollar', 'incredible'],
#  ['incredible'],
#  ['going', 'marry', 'blood', 'laughter'],
#  ['lucky', 'lucky', 'lucky'],
#  [],
#  ['totally'],
#  [],
#  [],
#  ['check', 'really', 'softball', 'recently'],
#  [],
#  ['totally', 'random', 'scholarship', 'u.s.c', 'softball'],
#  ['laughter', 'softball', 'unbelievable', 'pitch'],
#  ['softball', 'going', 'school', 'awesome'],
#  ['pitch',
#   'pitcher',
#   'though',
#   'pinch',
#   'hitter',
#   'mostly',
#   'guess',
#   'going',
#   'shortstop'],
#  [],
#  ['pinch', 'hitting', 'softball'],
#  ['incredible'],
#  ['amaze', 'everything'],
#  ['softball'],
#  ['housing', 'book', 'everything', 'incredible'],
#  ['everything', 'every', 'like-', 'trojan', 'sport', 'awesome'],
#  ['incredible'],
#  [],
#  [],
#  ['amaze', 'congratulations'],
#  ['thank'],
#  ['housing', 'though', "'cause", 'think', 'nice', 'place'],
#  [],
#  ['probably', 'victorian', 'house', 'around'],
#  [],
#  ['really',
#   'could',
#   'santa',
#   'monica',
#   'beach',
#   'venice',
#   'beach',
#   'little',
#   'dirty',
#   'though',
#   'venice',
#   'beach',
#   'malibu',
#   'right'],
#  ['venice', 'beach'],
#  ['mmhmm'],
#  ['side'],
#  ['would', 'commute', 'especially-', 'especially', 'going'],
#  ['professional', 'softball', 'player', 'malibu', 'laughter'],
#  ['francisco'],
#  ['commuting', 'malibu', 'would', 'ridiculous'],
#  ['would',
#   'depend',
#   'though',
#   'guess',
#   'would',
#   'worth',
#   'helicopter',
#   'helicopter',
#   'helipad',
#   'right',
#   'exactly'],
#  ['right', 'practice'],
#  ['clock', 'morning', 'practice', 'swimming', '--ballet', 'things'],
#  ['think', 'afternoon', "'cause", 'early', "'cause"],
#  ['softball', 'anywhere'],
#  ['night', 'game', 'night', 'game', 'morning', 'game', 'guess', 'thing'],
#  ['surprise'],
#  ['incredible'],
#  ['softball', 'really'],
#  ['softball'],
#  ['believe'],
#  ['nationally', 'rank'],
#  ['literally', 'walking', 'around'],
#  ['unbelievable'],
#  ['pretty'],
#  ['would', 'right'],
#  ['doubt', 'garbage', 'garbage'],
#  ['denigrate', 'think', 'great'],
#  ['really', 'sport', 'saying'],
#  ['softball', 'play', 'softball'],
#  ['totally', 'sport', 'talking'],
#  ["'cause", 'regular', 'baseball', 'sport'],
#  ['saying',
#   'think',
#   'great',
#   'think',
#   'incredibly',
#   'proud',
#   'especially',
#   'going',
#   'u.s.c'],
#  ['really', 'care', 'softball'],
#  ['drive', 'around', 'would'],
#  ['really', 'whole'],
#  ['game', 'stuff'],
#  ['teammate', 'people', 'softball'],
#  [],
#  ['police', 'officer', 'heavyset', 'mustache'],
#  ['really'],
#  [],
#  ["they're", 'like-'],
#  [],
#  ['garbage'],
#  ['rookie'],
#  [],
#  ['watch', 'years', 'force', 'carry', 'around', 'donut', 'pocket', 'laughter'],
#  ['going', 'mustache', 'force'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['try'],
#  [],
#  [],
#  ['looking', 'three', 'years', 'america', 'right'],
#  ['people', 'looking'],
#  ['guess', 'three', 'years', 'college', 'finish', 'little'],
#  ['think'],
#  ['sending',
#   'resume',
#   'everything',
#   'nothing',
#   'happening',
#   'living',
#   'loan',
#   'anymore',
#   'going',
#   'eventually',
#   'going',
#   'freak'],
#  ['think', 'might', 'attitude'],
#  ['attitude'],
#  ['sometimes', 'saying', 'just--'],
#  ['attitude', 'problem'],
#  ['maybe', 'frustrate', "'cause"],
#  ['anyone', 'anything'],
#  ['really', 'shake', 'audition', 'whatever'],
#  ['right'],
#  ['right'],
#  ['guess', 'getting', 'really'],
#  ['saying', 'looking', 'somebody'],
#  ['hire', 'seriously', 'anything', 'though', 'please', 'anything'],
#  ['saying',
#   'though',
#   'person',
#   'hire',
#   'somebody',
#   '--would',
#   'someone',
#   'angry',
#   'upset'],
#  [],
#  ['across', 'angry'],
#  [],
#  [],
#  ['little', 'listen'],
#  ['friend', 'stuff', 'honestly', 'stuff', 'please'],
#  ['handle'],
#  ['flying', 'handle', 'think', 'flying', 'handle'],
#  ['short'],
#  ['short'],
#  [],
#  ['bring'],
#  ['right', 'try', 'conversation'],
#  ['try', 'conversation', 'extremely', 'hostile', 'cutting'],
#  ["'cause"],
#  ['breathing'],
#  ['always', 'right', 'just--'],
#  ['finish', 'sentence', 'without', 'jumping'],
#  ['always', 'right'],
#  [],
#  ['excuse', 'everything'],
#  ['breathing'],
#  ['saying', 'maybe', 'information', 'produce'],
#  ['sponge', 'soak', 'information', 'three', 'years', 'dying'],
#  ['breathing'],
#  [],
#  ['think'],
#  ['field', 'looking'],
#  [],
#  [],
#  [],
#  ['please'],
#  ['little', 'information'],
#  ['hours'],
#  ['what-', 'flight'],
#  ['coming', 'atlanta'],
#  ['georgia'],
#  ['georgia'],
#  ['raise', 'voice'],
#  ['college', 'educate'],
#  ['speak', 'language'],
#  ['insinuate',
#   'college',
#   'education',
#   'that-',
#   'reason',
#   'make',
#   'better',
#   'person'],
#  ['listen', 'mouth'],
#  ['saying'],
#  ['sitting', 'hours'],
#  ['child'],
#  ['sixteen'],
#  ['people', 'toss', 'around', 'hanky'],
#  ['every', 'single'],
#  [],
#  ['details', 'details', 'anyhow'],
#  ['atlanta'],
#  ['atlanta'],
#  ['hours'],
#  ['little', 'black', 'wheel'],
#  [],
#  ['would', 'overhead', 'compartment', 'check'],
#  ['would', 'atlanta', 'atlanta'],
#  ['little'],
#  ['nothing', 'boarding', 'attendance', 'sorry', 'wherever'],
#  ['right',
#   'middle',
#   'different',
#   'people',
#   'crying',
#   'please',
#   'bloody',
#   'please',
#   'bring',
#   'bloody'],
#  ['unfortunate', 'going'],
#  ['--arriving'],
#  ['really', 'really', 'stressful', 'please'],
#  ['really', 'sorry'],
#  [],
#  ['offer', 'fifty', 'dollar', 'reimbursement', 'cards', 'airline'],
#  ['future'],
#  ['sorry', 'minute', 'saying', 'going'],
#  [],
#  [],
#  [],
#  [],
#  ['actually'],
#  ['someone', 'steal', 'people', 'steal'],
#  ['matter', 'publicize'],
#  ['people', 'would', 'airline'],
#  ['probably', 'people', 'company'],
#  ['little', 'could', 'easily', 'overhead', 'compartment', 'check'],
#  [],
#  ['computer', 'collecting', 'right'],
#  ['unfortunate'],
#  ['really', 'unfortunate', 'going', 'fire'],
#  [],
#  ['fifty', 'dollar', 'going', 'cover'],
#  ['could'],
#  ['maybe'],
#  [],
#  [],
#  [],
#  ['sitting', 'service', 'least', 'aggressive', 'search', 'stuff'],
#  ['plenty', 'aggressive', 'search', 'going', 'someone', 'take'],
#  ['right',
#   'plenty',
#   'aggressive',
#   'search',
#   'going',
#   'aggressive',
#   'search',
#   'drinking',
#   'coffee',
#   'smoking',
#   'cigarette'],
#  ['working', 'union', 'people', 'around'],
#  ['abuse'],
#  ['abuse', 'either', 'try', 'atlanta', 'stuff'],
#  ['fantastic'],
#  ['fifty', 'dollar', 'shopping', 'tomorrow'],
#  ['breathing'],
#  ['thank'],
#  [],
#  ['still', 'love', 'parent'],
#  ['style'],
#  ['thing'],
#  ['breathing', 'lovely', 'sweet'],
#  ['sorry'],
#  ['sorry'],
#  [],
#  ['thing', 'mother'],
#  [],
#  [],
#  [],
#  ['embarrass', 'since'],
#  ['planning', 'sneak', 'course', 'grant'],
#  ['would'],
#  [],
#  ['mother', 'point', 'would'],
#  ['would', 'guess', 'ask'],
#  ['guess', 'guess'],
#  ['breathing'],
#  ['annie'],
#  ['laughter'],
#  ['really', 'imagination'],
#  ['laughter'],
#  ['embarrass', 'porch', 'want', 'somewhere', 'place', 'fresh'],
#  [],
#  ['uncomfortable', 'wrong', 'somehow', 'anything'],
#  ['chris', 'ready'],
#  ['forever'],
#  ['almost', 'married', 'years'],
#  [],
#  ['start', 'write'],
#  ['something'],
#  ['every', 'since'],
#  [],
#  ['waiting', 'chris', 'ambiguous', 'finally', 'write'],
#  [],
#  [],
#  ['kiss', 'annie'],
#  ['beating', 'around'],
#  ['laughter'],
#  ['never',
#   'forgive',
#   'around',
#   'wonder',
#   'crazy',
#   'waiting',
#   'wonder',
#   'thinking'],
#  ['annie', 'going', 'going', 'happy'],
#  [],
#  ['kiss'],
#  ['larry', 'brother', 'chris'],
#  ['chris'],
#  ['drive', 'place'],
#  ['mother'],
#  ['nothing', "it's-"],
#  ['chris', 'letters', 'something', 'ashamed'],
#  ['suppose', 'going'],
#  [],
#  ['start'],
#  ['would'],
#  ['mix', 'things', 'overseas', 'command', 'company'],
#  [],
#  [],
#  [],
#  ['pretty'],
#  [],
#  ['thing'],
#  ['instance', 'rain', 'several', 'sock', 'pocket', 'little', 'thing'],
#  ['kill', 'exactly', 'little', 'selfish', 'would', 'today'],
#  ['watching', 'everything', 'destroy', 'thing', 'monument', 'responsibility'],
#  ['mmhmm'],
#  ['bring', 'earth', 'monument', 'thought', 'would', 'difference'],
#  ['incredible', 'whole', 'thing', 'random', 'accident'],
#  ['driving', 'seeing', 'refrigerator'],
#  ['things', 'drive', 'refrigerator', 'another'],
#  ['guess', 'include'],
#  ['still'],
#  ['annie'],
#  ['everything', 'earn', 'everything', 'understand'],
#  ['money',
#   'chris',
#   'nothing',
#   'wrong',
#   'money',
#   'father',
#   'hundred',
#   'plane',
#   'proud'],
#  ['annie', 'annie', 'going', 'fortune'],
#  ['would', 'fortune'],
#  [],
#  [],
#  [],
#  ['wonder'],
#  ['freda', 'know', 'would'],
#  [],
#  ['happen', 'sooner', 'later', 'going'],
#  ['breathing'],
#  ['darling'],
#  ['always', 'sweet'],
#  [],
#  ['happen', 'sooner', 'later'],
#  ['hello', 'hello', 'sorry'],
#  ['wrong', 'number', 'laughter'],
#  ['laughter', 'shiver', 'spine'],
#  ['shall', 'suddenly', 'us.[laughter'],
#  ['behave', 'exquisitely'],
#  ['perfect', 'poise'],
#  ['think', 'shall', 'curtsy'],
#  ['strange', 'things', 'ought', 'matter', 'dreadfully', 'matter', 'happy'],
#  ['happy'],
#  ['darling'],
#  ['think', 'whole', 'thing', 'cruel'],
#  ['beautiful', 'sacred', 'thing'],
#  ['meaning'],
#  ['quest', 'ultimate', 'truth'],
#  ['laugh', 'serious'],
#  ['darling', 'serious'],
#  [],
#  ['futile', 'moralist', 'unbearable', 'laugh', 'flippant'],
#  ['flippancy', 'bring', 'darn', 'light', 'sweetness'],
#  ['laugh', 'everything', 'laugh'],
#  ['course', 'figure', 'right'],
#  ['ludicrous', 'overbear'],
#  ['know'],
#  ['shall', 'always', 'bicker', 'fight'],
#  ['along', 'passion'],
#  [],
#  ['depend', 'play'],
#  ['happen', 'still', 'laugh'],
#  ['might'],
#  ['serious', 'enough'],
#  ['death', 'laughable', 'thing', 'cunning', 'little', 'mystery', 'mirror'],
#  ['think', 'talking', 'nonsense'],
#  ['everyone'],
#  ['superficial',
#   'philosopher',
#   'trumpets',
#   'squeaker',
#   'enjoy',
#   'party',
#   'small',
#   'idiotic',
#   'school',
#   'child'],
#  ['laughter'],
#  ['darling', 'worm', 'socket'],
#  ['elliott', 'worm'],
#  ['paint', 'green', 'naked', 'place', 'vendome', 'world'],
#  ['thank', 'darling', 'apply', 'except', 'another', 'woman'],
#  ['remember', 'awful', 'scene', 'venice'],
#  ['particular'],
#  ['paint', 'wooden', 'snake'],
#  ['charles', 'wiggle', 'beautifully'],
#  ['garbage'],
#  ['terrible', 'thing', 'hate'],
#  ['throw', 'window', 'grand', 'canal', 'never', 'forgive'],
#  [],
#  ['intermittently'],
#  [],
#  ['worst', 'cannes', 'curling', 'irons', 'burn', 'dressing'],
#  ['burn', 'towel', 'bathroom'],
#  ['rouser'],
#  ['laughter', 'first'],
#  [],
#  ['manager',
#   'found',
#   'rolling',
#   'floor',
#   'bite',
#   'scratching',
#   'panther',
#   'laughter',
#   'utterly',
#   'utterly',
#   'ridiculous'],
#  ['laughter', 'never', 'forget', 'laughter'],
#  ['laughter', 'younger'],
#  ['laughter', 'silly'],
#  ['however', 'believe', 'cause', 'peter', 'burden'],
#  ['nothing'],
#  [],
#  ['swimming', 'right'],
#  ['massive', 'celebration', 'death'],
#  ['hair', 'standing', 'giving', 'goose', 'bump'],
#  [],
#  ['think'],
#  [],
#  ['saying'],
#  ['think', 'ridiculous'],
#  ['certainly', 'slightly', 'exaggerate', 'scientific'],
#  [],
#  ['somebody', 'good', 'something', 'amaze', 'going', 'happen', 'beach'],
#  ['people'],
#  ['thing'],
#  ['everybody', 'belief', 'keep', 'excite', 'keep', 'coming'],
#  ['everybody', 'keep', 'thinking', 'right', 'action'],
#  ['start'],
#  ['talking', 'thing'],
#  ['sorry', 'still'],
#  ['question', 'period'],
#  ['insult'],
#  ['bug'],
#  ['different', 'idea', 'evening', 'suppose'],
#  ['suppose', 'anything', 'arrive'],
#  ['augie', 'going'],
#  [],
#  [],
#  ['never'],
#  ['miss', 'twice'],
#  ['twice', 'every', 'try'],
#  ['better', 'trust'],
#  ['pointless', 'waiting', 'santa', 'claus'],
#  ['whole',
#   'going',
#   'spend',
#   'beach',
#   'hands',
#   'clasp',
#   'expectantly',
#   'waiting',
#   'never'],
#  ['try', 'backwards'],
#  ['understand', 'anything', 'saying'],
#  ['figure', 'worst', 'thing'],
#  ['course'],
#  ['still', 'always', 'thinking', 'never'],
#  ['try', 'backwards', 'try', 'figure', 'exact', 'moment', 'worst'],
#  ['phone', 'marge', 'dinner', 'dish'],
#  ['shower', 'watching', 'grunions', 'running', 'tonight', 'great'],
#  ['putting', 'animal', 'getting', 'garage', 'and--'],
#  ['remember', 'first', 'years', 'right', 'married'],
#  ['thought',
#   'pregnant',
#   'bottle',
#   'champagne',
#   'glasses',
#   'ask',
#   'dance',
#   'shoes'],
#  ['dancing', 'soft', 'intimate', 'things', 'right', 'could'],
#  ['remember', 'thinking', 'finally', 'finally', 'happy', 'suppose'],
#  ['minute'],
#  ['dancing', 'beach', 'barefoot', 'drinking', 'champagne', 'bottle'],
#  ['driving',
#   'pass',
#   'knickerbocker',
#   'liquor',
#   'locker',
#   'would',
#   'champagne',
#   'wasting',
#   'something',
#   'right'],
#  ['times', 'right'],
#  ['rather', 'remember', 'things', 'rather', 'things'],
#  ['right', 'course'],
#  ['dance'],
#  [],
#  ['champagne'],
#  [],
#  ['shoes'],
#  [],
#  [],
#  ['married'],
#  ['divorce'],
#  [],
#  ['vacation'],
#  [],
#  ['carpet', 'poodle', 'suicide', 'cream'],
#  ['something', 'suppose'],
#  ['welcome', 'human'],
#  ['think',
#   'nothing',
#   'turn',
#   'suppose',
#   'think',
#   'grand',
#   'going',
#   'years',
#   'would',
#   'beach',
#   'argue'],
#  ['think', 'would', 'times', 'kleenex', 'think', 'flight', 'alaska'],
#  ['thought', 'going', 'cheek', 'bill', 'would', 'always', 'and--'],
#  [],
#  ['anything'],
#  [],
#  ['standing', 'beach', 'waiting', 'fighting'],
#  ['right'],
#  ['anything', 'thought', 'anything', 'would'],
#  ['neither'],
#  ['include', 'everything', 'understand', 'saying'],
#  [],
#  ['augie', 'really'],
#  ['wishing', 'somebody', 'somewhere'],
#  ['maybe', 'somebody'],
#  [],
#  ['happy'],
#  ['kid', 'heaven', 'augie', 'anything', 'rather'],
#  [],
#  ['ridiculous'],
#  ['probably',
#   'wish',
#   'somebody',
#   'someone',
#   'everything',
#   'seriously',
#   'someone',
#   'would',
#   'enjoy'],
#  ['actually', 'mention'],
#  ['maybe', 'wrong', 'right', 'person'],
#  ['seem'],
#  ['really', 'though'],
#  ['pretty', 'white'],
#  [],
#  ['augie', 'bring', 'refreshment'],
#  ['champagne'],
#  ['guess', 'glasses'],
#  [],
#  ['beginning', 'think', 'might', 'right', 'think', 'might'],
#  ['augie', 'sorry'],
#  [],
#  ['really', 'quiet', 'might'],
#  [],
#  [],
#  [],
#  [],
#  ['vega', 'awesome'],
#  ['hear'],
#  ['married'],
#  ['vega'],
#  [],
#  ['marry'],
#  ['chuck', 'laughter'],
#  ['propose'],
#  ['romantic'],
#  ['machine'],
#  ['wheel', 'fortune', 'slot'],
#  ['realize', 'thing', 'would', 'better', 'bride'],
#  ['turn'],
#  ['married'],
#  ['laughter', 'really', 'romantic'],
#  ['leaving'],
#  [],
#  ['going', 'honeymoon', 'cruise'],
#  ['going', 'citizenship', 'england', 'whatever'],
#  ['thought'],
#  ['think'],
#  ['going', 'citizen', 'though'],
#  ['visit'],
#  ['think'],
#  ['totally'],
#  [],
#  ['going', 'distance', 'thing', 'going'],
#  ['guess', "i'll-", 'guess', 'internet', 'husband.[laughter'],
#  ['another', 'those.[laughter'],
#  ['internet', 'boyfriend', 'guess', 'juggle', 'cheating'],
#  ['phone'],
#  ['laughter', 'calling'],
#  ['love'],
#  ['like'],
#  [],
#  ['think', 'seven', 'hundred', 'fifty', 'dollar'],
#  ['really', 'penny', 'slot'],
#  ['penny', 'slot', 'play'],
#  [],
#  [],
#  ['wheel', 'fortune', 'quarters', 'costs'],
#  [],
#  ['play', 'wheel', 'fortune', 'penny', 'giant', 'thing', 'like-'],
#  ['penny', 'always', 'spending', 'fifty', 'buck'],
#  ['fifty', 'buck', 'mmhmm'],
#  ['penny', 'minute'],
#  [],
#  ['married', 'child'],
#  ['awesome'],
#  ['laughter', 'baby'],
#  ['rename', 'brenda', 'lumber', 'janet'],
#  ['enough'],
#  ['need', 'state', 'laughter'],
#  [],
#  ['invite'],
#  ['bother'],
#  ['three', 'years', 'sudden'],
#  ['maybe', 'maybe', 'want'],
#  ['nobody', 'come', 'seven', 'hundred', 'mile'],
#  ['live', 'whole', 'would'],
#  ['breathing', 'anything'],
#  ['going', 'marry'],
#  ['thinking'],
#  [],
#  [],
#  ['going'],
#  ['listen'],
#  ['know'],
#  [],
#  ['still',
#   'single',
#   'still',
#   'single',
#   'probably',
#   'hundred',
#   'people',
#   'foolish',
#   'wait'],
#  ['wait'],
#  ['know', 'faithful', 'dark', 'moment', 'think', 'waiting', 'right'],
#  ['arguing'],
#  ['nobody',
#   'house',
#   'dare',
#   'faith',
#   'stranger',
#   'might',
#   'father',
#   'brother'],
#  [],
#  ['coming', 'think', 'notice', 'since', 'chris', 'invite'],
#  ['stand', 'nonsense'],
#  [],
#  ['coming',
#   'laugh',
#   'laugh',
#   'happen',
#   'night',
#   'come',
#   'sleep',
#   'memorial',
#   'break',
#   'piece'],
#  ['breathing'],
#  [],
#  ['believe',
#   'detroit',
#   'miss',
#   'longer',
#   'larry',
#   'believe',
#   'believe',
#   'believe'],
#  [],
#  ['right', 'right', 'right'],
#  ['shaking'],
#  [],
#  ['matter'],
#  [],
#  ['younger'],
#  ['silly'],
#  ['however', 'believe', 'cause', 'peter', 'burden'],
#  ['nothing'],
#  ['nothing', 'present'],
#  ['present', 'trivial', 'little', 'brooch'],
#  ['bristle', 'diamond', 'worst', 'possible', 'taste'],
#  ['still', 'often', 'pretty'],
#  ['torture', 'peter', 'burden'],
#  ['work', 'whole', 'thing', 'jealous', 'imagination'],
#  [],
#  [],
#  [],
#  ['pleasure'],
#  [],
#  ['suspicious', 'nosey', 'never', 'would', 'know', 'thing'],
#  ['point'],
#  ['bore', 'conversation'],
#  ['bore', 'stiff', 'garbage', 'brandy'],
#  ['thank'],
#  ['little', 'think'],
#  ['already', 'three', 'glasses'],
#  ['particular', 'reason', 'anyhow', 'small'],
#  ['think', 'silly', 'thing'],
#  ['hardly', 'three', 'glasses', 'liquor', 'whole', 'evening', 'going'],
#  ['become', 'habit'],
#  ['grand', 'happen', 'moment'],
#  ['stupid'],
#  ['really', 'amanda'],
#  [],
#  ['nothing'],
#  ['going', 'somewhere'],
#  ['making', 'fascinate'],
#  ['reply', 'break', 'heart'],
#  ['woman', 'allure'],
#  ['matter', 'perfectly'],
#  [],
#  [],
#  [],
#  ['really', 'brandy', 'would', 'little', 'disagreeable'],
#  ['funny', 'work', 'wonder'],
#  ['little', 'adder'],
#  ['adder', 'sting'],
#  ['nonsense', 'venom', 'behind', 'fang'],
#  ['sting', 'understand', 'hoops'],
#  ['peter', 'burden', 'divorce'],
#  ['quite'],
#  ['suppose', 'suppose', 'riotous', 'restraint', 'never', 'really', 'anyhow'],
#  ['business'],
#  ['quite', 'insufferable', 'expect', 'drunk'],
#  ['think', 'least', 'drunk'],
#  ['always'],
#  ['think',
#   'mention',
#   'three',
#   'minute',
#   'liquor',
#   'glasses',
#   'whole',
#   'evening',
#   'child',
#   'drunk'],
#  ['contrary', 'child', 'violently', 'drunk', 'glass', 'brandy'],
#  ['interest',
#   'amanda',
#   'child',
#   'child',
#   'child',
#   'little',
#   'conversation',
#   'going',
#   'intemperate'],
#  [],
#  [],
#  ['funny', 'darling', 'brandy'],
#  ['laughter', 'think'],
#  ['better', 'people', 'upstairs'],
#  [],
#  ['people', 'upstairs', 'photographer', 'studio'],
#  ['people', 'downstairs'],
#  ['tunis'],
#  ['tunis'],
#  ['please'],
#  ['thing'],
#  ['insist', 'boorish', 'idiotic'],
#  ['driving'],
#  ['temperamental', 'control'],
#  [],
#  ['listen', 'listen', 'tire', 'listening', 'sadistic', 'bully'],
#  ['amanda', 'listen', 'listen'],
#  ['amuse', 'indeed'],
#  ['conceited', 'overbear', 'utterly', 'impossible'],
#  ['temper', 'loose', 'living', 'wicked', 'little', 'beast', 'never'],
#  ['finally', 'forever'],
#  ['going'],
#  [],
#  [],
#  ['cruel',
#   'fiend',
#   'loathe',
#   'marry',
#   'never',
#   'never',
#   'never',
#   'torment',
#   'brute',
#   'beast'],
#  ['would', 'marry', 'crawling', 'bend', 'temper', 'little', 'wench', 'never'],
#  [],
#  ['excuse'],
#  ['form'],
#  [],
#  [],
#  ['problem'],
#  [],
#  [],
#  ['standing', 'beginning', 'direct'],
#  ['filling', 'particular'],
#  ['problem', 'change'],
#  ['z.x.four'],
#  ["can't--", 'z.x.four', 'going', 'z.x.four', 'different'],
#  ['getting', 'wallet', 'steal'],
#  ['another', 'prove', 'actually'],
#  ['suppose', 'without', 'person', 'first', 'place'],
#  ['along', 'along', 'without'],
#  [],
#  ['another', 'separate'],
#  ['birth', 'certificate'],
#  ['birth', 'certificate', 'passport', 'student', 'school', 'anything'],
#  ['birth', 'certificate'],
#  ['wallet', 'steal', 'anything', 'credit', 'cards', 'things'],
#  ['access'],
#  ['control'],
#  ['understand', 'complicate', 'people', 'simple'],
#  ['working'],
#  ['actually'],
#  ['clearly', 'supervisor', 'something'],
#  ['supervisor', 'supervisor', 'right'],
#  ['would', 'would', 'appreciate'],
#  [],
#  ['great', 'believe'],
#  ['course',
#   'little',
#   'coast',
#   'light',
#   'people',
#   'everything',
#   'midnight',
#   'always',
#   'start',
#   'midnight',
#   'midnight'],
#  [],
#  [],
#  ['think'],
#  [],
#  ['though',
#   'although',
#   'probably',
#   'probably',
#   'right',
#   'probably',
#   'going',
#   'unmistakable',
#   'right'],
#  ['great', 'awesome', 'forget'],
#  ['flashlight', 'could', 'forget', 'flashlight', 'god--'],
#  ['flashlight'],
#  ['flashlight', 'silver'],
#  ['flashlight'],
#  ['whose'],
#  ['flashlight'],
#  ['course'],
#  ['saying', 'flashlight', 'somehow', 'suppose'],
#  [],
#  ['course', 'flashlight', 'flashlight', 'flashlight'],
#  ['bring', 'believe', 'forget'],
#  ['though', 'always', 'remember'],
#  [],
#  ['right', 'jacket', 'jacket'],
#  [],
#  ['bring', 'blanket', 'blanket', 'blanket', 'would', 'ticket', 'right'],
#  ['wrong'],
#  [],
#  ['excite', 'right'],
#  ['believe', 'house', 'without', 'zip'],
#  [],
#  ['wonder'],
#  ['chuckle'],
#  ['wonder', 'talking'],
#  ['vibration', 'around'],
#  [],
#  ['jacket'],
#  ['eleven'],
#  ['kid', 'around', 'point', 'coming'],
#  ['point'],
#  ['right'],
#  ['point'],
#  ['point'],
#  [],
#  ['point', 'point', 'point', 'coming', 'around'],
#  [],
#  ['particularly'],
#  [],
#  ['stupid'],
#  ['stupid', 'natural', 'phenomenon'],
#  ['people',
#   'kansas',
#   'would',
#   'plane',
#   'ticket',
#   'hotel',
#   'reservation',
#   'forty',
#   'minutes'],
#  ['little', 'ocean', 'around'],
#  ['flop',
#   'around',
#   'spawn',
#   'mating',
#   'something',
#   'highlight',
#   'little',
#   'life'],
#  ['excite', 'landing', 'talking', 'nobody'],
#  [],
#  ['augie'],
#  ['whatever',
#   'something',
#   'swallow',
#   'return',
#   'capistrano',
#   'lemming',
#   'jump',
#   'cliff'],
#  ['little',
#   'unexplainable',
#   'little',
#   'magic',
#   'little',
#   'mystery',
#   'interest'],
#  [],
#  [],
#  [],
#  ['right'],
#  ['though', 'first', 'night'],
#  ['remember', 'distinctively', 'excite', 'realize', 'stub'],
#  ['remember', 'shoes', 'pantie', 'throat', 'fight', 'grunions'],
#  ['though'],
#  ['either'],
#  ['telling', 'better'],
#  ['trust', 'instinct', 'things', 'think', 'right', 'interest', 'think'],
#  ['silver', 'heading'],
#  ['invitation', 'direction'],
#  ['turn', 'california', 'coast', 'start', 'swimming'],
#  ['little', 'release', 'cracker', 'inside', 'little', 'body', 'turn'],
#  ['start', 'swimming', 'swimming', 'would', 'bring', 'point'],
#  ['urgency', 'single', 'mindedness'],
#  ['crazy', 'giving', 'goose', 'bump', 'hair', 'standing'],
#  [],
#  [],
#  ['going'],
#  ['maybe'],
#  [],
#  ['could', 'first', 'still'],
#  ['break'],
#  [],
#  ['clock', 'morning', 'hear', 'crack', 'look', 'standing', 'right', 'crack'],
#  ['clock', 'morning'],
#  [],
#  ['dreaming', 'walking', 'around'],
#  ['guess'],
#  ['getting', 'meaning'],
#  ['meaning', 'thing', 'terrible', 'mistake', 'father'],
#  [],
#  ['dishonest', 'thing', 'always', 'pay'],
#  ['dishonest'],
#  ['larry', 'coming', 'allow', 'thinking', 'believe'],
#  ['argue'],
#  ['argue', 'realize', 'nobody', 'belief', 'larry', 'alive'],
#  ['night', 'thinking', 'dreaming', 'contradict', 'anymore', 'years'],
#  [],
#  [],
#  ['proof', 'proof'],
#  ['three', 'years', 'nobody', 'come', 'three', 'years', 'insane'],
#  ['father', 'grave'],
#  [],
#  ['trouble',
#   'newspaper',
#   'every',
#   'month',
#   'come',
#   'going',
#   'larry',
#   'just--'],
#  ['right', 'right', 'right', 'ask', 'annie', 'right'],
#  [],
#  [],
#  ['story'],
#  ['going', 'marry'],
#  ['business', 'chris'],
#  ['business'],
#  ['enough'],
#  ['right', 'ahead'],
#  ['father', 'going'],
#  ['business'],
#  ['saying'],
#  ['sometimes',
#   'infuriate',
#   'business',
#   'father',
#   'throw',
#   'talent',
#   'ignore',
#   'things'],
#  ['ignore', 'ignore', 'larry'],
#  ['larry'],
#  [],
#  ['mother', 'point'],
#  ['father', 'point', 'chris', 'still', 'think', 'still', 'alive', 'larry'],
#  [],
#  [],
#  ['telling'],
#  ['every',
#   'reach',
#   'something',
#   'afraid',
#   'people',
#   'suffer',
#   'whole',
#   'bloody'],
#  [],
#  ['considerate', 'fellow', 'nothing', 'wrong'],
#  [],
#  ['ask', 'annie'],
#  ['want', 'settle', 'first'],
#  ['going', 'marry', 'maybe', 'feel', 'father'],
#  ['letters', 'though', 'think', 'pretty', 'forget'],
#  ['thrash', 'father', 'avoid'],
#  ['trouble', 'enough', 'woman', 'never'],
#  ['woman'],
#  ['annie'],
#  [],
#  ['great', 'reason', 'reason'],
#  [],
#  ['since', 'years'],
#  ['bring', 'years', 'think', 'someone', 'think', 'annie'],
#  ['diagram'],
#  ['diagram'],
#  ['think', 'coming', 'chris'],
#  ['marry', 'pronounce'],
#  ['going', 'father'],
#  ['right', 'breathing'],
#  ['thought'],
#  ['given',
#   'three',
#   'years',
#   'thought',
#   'wait',
#   'father',
#   'would',
#   'forget',
#   'larry',
#   'could',
#   'regular',
#   'wedding',
#   'everyone',
#   'would',
#   'happy'],
#  ['somewhere'],
#  [],
#  ['married', 'somewhere', 'maybe'],
#  ['crazy'],
#  ['sucker'],
#  ['business'],
#  ['business', 'business', 'inspire'],
#  ['inspire'],
#  ['money', 'happy'],
#  ['family', 'somebody', 'annie', 'center'],
#  ['would', 'leave', 'business'],
#  ['would'],
#  ['think'],
#  [],
#  ['right', 'think', 'working', 'chris', 'whole', 'shooting', 'match'],
#  [],
#  ['think'],
#  ['thinking'],
#  ['understand'],
#  ['pretty', 'tough'],
#  [],
#  [],
#  ['try', 'craig'],
#  ['craig', 'internet', 'thing'],
#  [],
#  ['that--', 'escort', 'services', 'things'],
#  ['regular'],
#  ['looking',
#   'figure',
#   'that--',
#   'think',
#   'things',
#   'monster',
#   'reliable',
#   'random',
#   'board'],
#  [],
#  ...]

# %%
df_lda2
# Out:
# 0       Next.\n Yes, me. Okay, okay here we go.\n My ...
# 1       Hey, Joy come in here.\n What's happening?\n ...
# 2       The craziest thing just happened to me.\n Wha...
# 3       Check this out.  You know how I've told you I...
# 4       You seem kind of down.\n I'm just mad.\n How ...
#                              ...
# 139     What is it?\n Sweetheart, I've got to tell yo...
# 140     Ryan, what's wrong?\n I just got some bad new...
# 141     Guess what?\n What?\n I got it.  I got accept...
# 142     Hi. Um-  My luggage didn't come out of the co...
# 143     Uh, God.  I don't know what to do anymore.  L...
# Name: Text, Length: 144, dtype: object

# %% [markdown]
# First, we are creating a dictionary from the data, then convert to bag-of-words corpus and save the dictionary and corpus for future use.

# %%
from gensim import corpora
dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]

import pickle
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')

# %%
import gensim
NUM_TOPICS = 10
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('model5.gensim')
topics = ldamodel.print_topics(num_words=5)
for topic in topics:
    print(topic)
# Out:
# (0, '0.404*"sorry" + 0.026*"start" + 0.019*"excite" + 0.016*"child" + 0.015*"talking"')
# (1, '0.056*"understand" + 0.043*"point" + 0.032*"great" + 0.032*"dollar" + 0.027*"try"')
# (2, '0.068*"thing" + 0.065*"something" + 0.055*"would" + 0.050*"little" + 0.050*"never"')
# (3, '0.121*"really" + 0.043*"annie" + 0.027*"stuff" + 0.019*"exactly" + 0.019*"would"')
# (4, '0.147*"think" + 0.055*"anything" + 0.038*"still" + 0.030*"course" + 0.026*"would"')
# (5, '0.051*"people" + 0.046*"suppose" + 0.041*"always" + 0.035*"happen" + 0.027*"flashlight"')
# (6, '0.039*"years" + 0.038*"business" + 0.033*"happy" + 0.032*"three" + 0.025*"want"')
# (7, '0.063*"could" + 0.057*"laughter" + 0.035*"remember" + 0.034*"believe" + 0.029*"things"')
# (8, '0.182*"right" + 0.053*"maybe" + 0.023*"guess" + 0.022*"getting" + 0.018*"somebody"')
# (9, '0.215*"going" + 0.026*"nothing" + 0.025*"thank" + 0.023*"happen" + 0.021*"alright"')

# %%
dictionary = gensim.corpora.Dictionary.load('dictionary.gensim')
corpus = pickle.load(open('corpus.pkl', 'rb'))
lda = gensim.models.ldamodel.LdaModel.load('model5.gensim')

# %% [markdown]
# ### trying for doc-topic distribution using Gensim method

# %%
df_lda2
# Out:
# 0       Next.\n Yes, me. Okay, okay here we go.\n My ...
# 1       Hey, Joy come in here.\n What's happening?\n ...
# 2       The craziest thing just happened to me.\n Wha...
# 3       Check this out.  You know how I've told you I...
# 4       You seem kind of down.\n I'm just mad.\n How ...
#                              ...
# 139     What is it?\n Sweetheart, I've got to tell yo...
# 140     Ryan, what's wrong?\n I just got some bad new...
# 141     Guess what?\n What?\n I got it.  I got accept...
# 142     Hi. Um-  My luggage didn't come out of the co...
# 143     Uh, God.  I don't know what to do anymore.  L...
# Name: Text, Length: 144, dtype: object

# %%
topic = []
for k in range(0,144):
    max_p = 0
    max_clsuter = 0
    list_temp = lda[corpus[k]]
    for i in range(0, len(lda[corpus[k]])):
                if list_temp[i][1] > max_p:
                    max_p = list_temp[i][1]
                    max_clsuter = list_temp[i][0]
    topic.append(max_clsuter)
print(len(topic))
# Out:
# 144

# %%
df_lda2['topic'] = topic
df_lda2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0         Next.\n Yes, me. Okay, okay here we go.\n My ...
# 1         Hey, Joy come in here.\n What's happening?\n ...
# 2         The craziest thing just happened to me.\n Wha...
# 3         Check this out.  You know how I've told you I...
# 4         You seem kind of down.\n I'm just mad.\n How ...
#                                ...
# 140       Ryan, what's wrong?\n I just got some bad new...
# 141       Guess what?\n What?\n I got it.  I got accept...
# 142       Hi. Um-  My luggage didn't come out of the co...
# 143       Uh, God.  I don't know what to do anymore.  L...
# topic    [0, 0, 0, 3, 0, 9, 0, 5, 5, 0, 9, 9, 8, 0, 0, ...
# Name: Text, Length: 145, dtype: object

# %%
len(lda[corpus[0]])
# Out:
# 10

# %%
lda[corpus[2]]
# Out:
# [(0, 0.1),
#  (1, 0.1),
#  (2, 0.1),
#  (3, 0.1),
#  (4, 0.1),
#  (5, 0.1),
#  (6, 0.1),
#  (7, 0.1),
#  (8, 0.1),
#  (9, 0.1)]

# %%
list1 = lda[corpus[0]]
type(lda[corpus[0]])
# Out:
# list

# %%
list1[1][1]
# Out:
# 0.1

# %%
lda[corpus[5]]
# Out:
# [(0, 0.025000002),
#  (1, 0.025000002),
#  (2, 0.025000002),
#  (3, 0.025000002),
#  (4, 0.025000002),
#  (5, 0.025009241),
#  (6, 0.2750407),
#  (7, 0.025005545),
#  (8, 0.025000002),
#  (9, 0.5249445)]

# %%
df_lda2.to_csv(r'IS733_dataset_LDA.csv')

# %%
df_lda2 = pd.read_csv("IS733_dataset_LDA.csv")

# %%
lda_feature=[]
for i in range(0,144):
  lda_feature.append(lda[corpus[i]])
lda_feature
# Out:
# [[(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.55),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.05),
#   (9, 0.05)],
#  [(0, 0.36666664),
#   (1, 0.03333333),
#   (2, 0.03333333),
#   (3, 0.03333333),
#   (4, 0.03333333),
#   (5, 0.36666667),
#   (6, 0.03333333),
#   (7, 0.03333333),
#   (8, 0.03333333),
#   (9, 0.03333333)],
#  [(0, 0.025000002),
#   (1, 0.025000002),
#   (2, 0.025000002),
#   (3, 0.025000002),
#   (4, 0.025000002),
#   (5, 0.025006324),
#   (6, 0.27504057),
#   (7, 0.025005544),
#   (8, 0.025000002),
#   (9, 0.5249475)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.050000004),
#   (1, 0.050000004),
#   (2, 0.050000004),
#   (3, 0.050000004),
#   (4, 0.050000004),
#   (5, 0.54997694),
#   (6, 0.050000004),
#   (7, 0.050000004),
#   (8, 0.050000004),
#   (9, 0.05002303)],
#  [(0, 0.016666666),
#   (1, 0.016666666),
#   (2, 0.18333888),
#   (3, 0.016666666),
#   (4, 0.016666666),
#   (5, 0.6833261),
#   (6, 0.016666666),
#   (7, 0.016666666),
#   (8, 0.016667293),
#   (9, 0.016667692)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.033333335),
#   (1, 0.033333335),
#   (2, 0.033333335),
#   (3, 0.3666099),
#   (4, 0.033333335),
#   (5, 0.033333335),
#   (6, 0.033333335),
#   (7, 0.033333335),
#   (8, 0.033333335),
#   (9, 0.3667234)],
#  [(0, 0.03333601),
#   (1, 0.033333335),
#   (2, 0.033333335),
#   (3, 0.033333335),
#   (4, 0.033333335),
#   (5, 0.033333335),
#   (6, 0.033333335),
#   (7, 0.033333335),
#   (8, 0.033345327),
#   (9, 0.6999853)],
#  [(0, 0.05000589),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.5499784),
#   (9, 0.050015736)],
#  [(0, 0.60998946),
#   (1, 0.010001981),
#   (3, 0.110000156),
#   (5, 0.21000049),
#   (6, 0.010004679),
#   (8, 0.010002055),
#   (9, 0.0100012105)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.050000004),
#   (1, 0.050000004),
#   (2, 0.050000004),
#   (3, 0.050000004),
#   (4, 0.050000004),
#   (5, 0.050000004),
#   (6, 0.050000004),
#   (7, 0.050000004),
#   (8, 0.55),
#   (9, 0.050000004)],
#  [(0, 0.55),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.05),
#   (9, 0.05)],
#  [(0, 0.016666668),
#   (1, 0.016666668),
#   (2, 0.016666668),
#   (3, 0.18334626),
#   (4, 0.016666668),
#   (5, 0.1833387),
#   (6, 0.016666668),
#   (7, 0.016666668),
#   (8, 0.51664776),
#   (9, 0.016667275)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.033337258),
#   (1, 0.033333335),
#   (2, 0.033335406),
#   (3, 0.033333335),
#   (4, 0.033337235),
#   (5, 0.36665902),
#   (6, 0.033333335),
#   (7, 0.033333335),
#   (8, 0.36665142),
#   (9, 0.03334636)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.55),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.05),
#   (9, 0.05)],
#  [(0, 0.050000004),
#   (1, 0.050000004),
#   (2, 0.050000004),
#   (3, 0.050000004),
#   (4, 0.55),
#   (5, 0.050000004),
#   (6, 0.050000004),
#   (7, 0.050000004),
#   (8, 0.050000004),
#   (9, 0.050000004)],
#  [(0, 0.033333335),
#   (1, 0.033333335),
#   (2, 0.033333335),
#   (3, 0.033333335),
#   (4, 0.7),
#   (5, 0.033333335),
#   (6, 0.033333335),
#   (7, 0.033333335),
#   (8, 0.033333335),
#   (9, 0.033333335)],
#  [(0, 0.03333578),
#   (1, 0.033333335),
#   (2, 0.033333335),
#   (3, 0.033333335),
#   (4, 0.36666438),
#   (5, 0.033333335),
#   (6, 0.033333335),
#   (7, 0.033335734),
#   (8, 0.033333335),
#   (9, 0.36666414)],
#  [(0, 0.050000004),
#   (1, 0.050000004),
#   (2, 0.050000004),
#   (3, 0.050000004),
#   (4, 0.050000004),
#   (5, 0.050000004),
#   (6, 0.050000004),
#   (7, 0.050000004),
#   (8, 0.55),
#   (9, 0.050000004)],
#  [(0, 0.02000199),
#   (1, 0.02),
#   (2, 0.02),
#   (3, 0.02),
#   (4, 0.5947793),
#   (5, 0.02),
#   (6, 0.02),
#   (7, 0.020000298),
#   (8, 0.24521382),
#   (9, 0.020004548)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.549982),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.050003253),
#   (8, 0.05001479),
#   (9, 0.05)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.55),
#   (9, 0.05)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.21999867),
#   (1, 0.2200015),
#   (2, 0.02),
#   (3, 0.02),
#   (4, 0.02),
#   (5, 0.02),
#   (6, 0.41999984),
#   (7, 0.02),
#   (8, 0.02),
#   (9, 0.02)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.55),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.05),
#   (9, 0.05)],
#  [(0, 0.55),
#   (1, 0.050000004),
#   (2, 0.050000004),
#   (3, 0.050000004),
#   (4, 0.050000004),
#   (5, 0.050000004),
#   (6, 0.050000004),
#   (7, 0.050000004),
#   (8, 0.050000004),
#   (9, 0.050000004)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.3666662),
#   (1, 0.36666712),
#   (2, 0.03333333),
#   (3, 0.03333333),
#   (4, 0.03333333),
#   (5, 0.03333333),
#   (6, 0.03333333),
#   (7, 0.03333333),
#   (8, 0.03333333),
#   (9, 0.03333333)],
#  [(0, 0.033333335),
#   (1, 0.033333335),
#   (2, 0.033333335),
#   (3, 0.033333335),
#   (4, 0.033333335),
#   (5, 0.033333335),
#   (6, 0.7),
#   (7, 0.033333335),
#   (8, 0.033333335),
#   (9, 0.033333335)],
#  [(0, 0.033333335),
#   (1, 0.033333335),
#   (2, 0.033333335),
#   (3, 0.033333335),
#   (4, 0.033333335),
#   (5, 0.033333335),
#   (6, 0.7),
#   (7, 0.033333335),
#   (8, 0.033333335),
#   (9, 0.033333335)],
#  [(0, 0.36666557),
#   (1, 0.033333335),
#   (2, 0.033333335),
#   (3, 0.033333335),
#   (4, 0.033333335),
#   (5, 0.36666775),
#   (6, 0.033333335),
#   (7, 0.033333335),
#   (8, 0.033333335),
#   (9, 0.033333335)],
#  [(0, 0.033333335),
#   (1, 0.033333335),
#   (2, 0.033333335),
#   (3, 0.033333335),
#   (4, 0.033333335),
#   (5, 0.36675113),
#   (6, 0.033333335),
#   (7, 0.36658216),
#   (8, 0.033333335),
#   (9, 0.033333335)],
#  [(0, 0.033333335),
#   (1, 0.033333335),
#   (2, 0.033339955),
#   (3, 0.033333335),
#   (4, 0.033333335),
#   (5, 0.6999934),
#   (6, 0.033333335),
#   (7, 0.033333335),
#   (8, 0.033333335),
#   (9, 0.033333335)],
#  [(0, 0.025000002),
#   (1, 0.27500066),
#   (2, 0.025000002),
#   (3, 0.27499995),
#   (4, 0.025000002),
#   (5, 0.025000002),
#   (6, 0.025000002),
#   (7, 0.025000002),
#   (8, 0.27499944),
#   (9, 0.025000002)],
#  [(0, 0.549994),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.050006002),
#   (8, 0.05),
#   (9, 0.05)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.27499855),
#   (1, 0.524994),
#   (2, 0.025007432),
#   (3, 0.025),
#   (4, 0.025),
#   (5, 0.025),
#   (6, 0.025),
#   (7, 0.025),
#   (8, 0.025),
#   (9, 0.025)],
#  [(0, 0.27499774),
#   (1, 0.5250001),
#   (2, 0.025),
#   (3, 0.025),
#   (4, 0.025),
#   (5, 0.025),
#   (6, 0.025),
#   (7, 0.025002176),
#   (8, 0.025),
#   (9, 0.025)],
#  [(0, 0.36671162),
#   (1, 0.033333335),
#   (2, 0.033333335),
#   (3, 0.033333335),
#   (4, 0.033333335),
#   (5, 0.3666217),
#   (6, 0.033333335),
#   (7, 0.033333335),
#   (8, 0.033333335),
#   (9, 0.033333335)],
#  [(0, 0.014285714),
#   (1, 0.014285714),
#   (2, 0.15714249),
#   (3, 0.29999486),
#   (4, 0.014285714),
#   (5, 0.15714358),
#   (6, 0.014286906),
#   (7, 0.014287022),
#   (8, 0.30000195),
#   (9, 0.014286072)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.55),
#   (9, 0.05)],
#  [(0, 0.025000002),
#   (1, 0.025000002),
#   (2, 0.77499706),
#   (3, 0.025000002),
#   (4, 0.025000002),
#   (5, 0.02500293),
#   (6, 0.025000002),
#   (7, 0.025000002),
#   (8, 0.025000002),
#   (9, 0.025000002)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.55),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.05),
#   (9, 0.05)],
#  [(0, 0.025),
#   (1, 0.025),
#   (2, 0.5249981),
#   (3, 0.025),
#   (4, 0.025),
#   (5, 0.025),
#   (6, 0.025),
#   (7, 0.025),
#   (8, 0.27500185),
#   (9, 0.025)],
#  [(0, 0.025),
#   (1, 0.025),
#   (2, 0.52499896),
#   (3, 0.025),
#   (4, 0.025),
#   (5, 0.025),
#   (6, 0.025),
#   (7, 0.27500102),
#   (8, 0.025),
#   (9, 0.025)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.033333335),
#   (1, 0.033333335),
#   (2, 0.033333335),
#   (3, 0.033333335),
#   (4, 0.03333509),
#   (5, 0.36666158),
#   (6, 0.36666644),
#   (7, 0.033333335),
#   (8, 0.033333335),
#   (9, 0.033336904)],
#  [(0, 0.18333156),
#   (1, 0.016666668),
#   (2, 0.016666668),
#   (3, 0.016666668),
#   (4, 0.01666689),
#   (5, 0.51666903),
#   (6, 0.016666668),
#   (7, 0.016666668),
#   (8, 0.18333198),
#   (9, 0.01666716)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.02),
#   (1, 0.02),
#   (2, 0.02),
#   (3, 0.02),
#   (4, 0.02),
#   (5, 0.02),
#   (6, 0.02),
#   (7, 0.02),
#   (8, 0.020006627),
#   (9, 0.8199934)],
#  [(0, 0.55),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.05),
#   (9, 0.05)],
#  [(0, 0.23334405),
#   (1, 0.011111111),
#   (2, 0.12220836),
#   (3, 0.45554987),
#   (4, 0.011111111),
#   (5, 0.011114721),
#   (6, 0.011111111),
#   (7, 0.011111111),
#   (8, 0.122227415),
#   (9, 0.011111111)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.014285713),
#   (1, 0.014285714),
#   (2, 0.014285714),
#   (3, 0.014285714),
#   (4, 0.014285714),
#   (5, 0.44281238),
#   (6, 0.014285714),
#   (7, 0.014285714),
#   (8, 0.014285713),
#   (9, 0.44290188)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.049999993),
#   (1, 0.049999993),
#   (2, 0.049999993),
#   (3, 0.049999993),
#   (4, 0.049999993),
#   (5, 0.049999993),
#   (6, 0.049999993),
#   (7, 0.049999993),
#   (8, 0.049999993),
#   (9, 0.55)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.55),
#   (9, 0.05)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.02),
#   (1, 0.02),
#   (2, 0.22000086),
#   (3, 0.02),
#   (4, 0.02),
#   (5, 0.22000019),
#   (6, 0.21999605),
#   (7, 0.02000446),
#   (8, 0.21999845),
#   (9, 0.02)],
#  [(0, 0.049999993),
#   (1, 0.55),
#   (2, 0.049999993),
#   (3, 0.049999993),
#   (4, 0.049999993),
#   (5, 0.049999993),
#   (6, 0.049999993),
#   (7, 0.049999993),
#   (8, 0.049999993),
#   (9, 0.049999993)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.033333335),
#   (1, 0.366758),
#   (2, 0.033333335),
#   (3, 0.03333334),
#   (4, 0.03333334),
#   (5, 0.03333334),
#   (6, 0.033333335),
#   (7, 0.033333335),
#   (8, 0.033333335),
#   (9, 0.36657533)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.36666635),
#   (1, 0.033333335),
#   (2, 0.033333335),
#   (3, 0.033335563),
#   (4, 0.033333335),
#   (5, 0.033333335),
#   (6, 0.36666372),
#   (7, 0.033333335),
#   (8, 0.033333335),
#   (9, 0.03333436)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.050007854),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.54999214),
#   (9, 0.05)],
#  [(0, 0.010000864),
#   (1, 0.010000002),
#   (2, 0.11000824),
#   (3, 0.210019),
#   (4, 0.11000786),
#   (5, 0.0100001795),
#   (6, 0.010000002),
#   (7, 0.1100083),
#   (8, 0.010007757),
#   (9, 0.4099478)],
#  [(0, 0.049999993),
#   (1, 0.049999993),
#   (2, 0.55),
#   (3, 0.049999993),
#   (4, 0.049999993),
#   (5, 0.049999993),
#   (6, 0.049999993),
#   (7, 0.049999993),
#   (8, 0.049999993),
#   (9, 0.049999993)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.050004784),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.54999524),
#   (8, 0.05),
#   (9, 0.05)],
#  [(0, 0.033333335),
#   (1, 0.033333335),
#   (2, 0.033333335),
#   (3, 0.033333335),
#   (4, 0.033333335),
#   (5, 0.033333335),
#   (6, 0.3666675),
#   (7, 0.033333335),
#   (8, 0.36666584),
#   (9, 0.033333335)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.55),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.05),
#   (9, 0.05)],
#  [(0, 0.050000004),
#   (1, 0.050000004),
#   (2, 0.050000004),
#   (3, 0.050000004),
#   (4, 0.050000004),
#   (5, 0.05000001),
#   (6, 0.050000004),
#   (7, 0.54999995),
#   (8, 0.050000004),
#   (9, 0.050000004)],
#  [(0, 0.033333335),
#   (1, 0.69999623),
#   (2, 0.033333335),
#   (3, 0.033335503),
#   (4, 0.033333335),
#   (5, 0.033333335),
#   (6, 0.033333335),
#   (7, 0.033334915),
#   (8, 0.033333335),
#   (9, 0.033333335)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.033333335),
#   (1, 0.033333335),
#   (2, 0.033333335),
#   (3, 0.033333335),
#   (4, 0.033333335),
#   (5, 0.033333335),
#   (6, 0.033333335),
#   (7, 0.36668244),
#   (8, 0.3666509),
#   (9, 0.033333335)],
#  [(0, 0.025000002),
#   (1, 0.025000002),
#   (2, 0.025000002),
#   (3, 0.02500385),
#   (4, 0.025000002),
#   (5, 0.025000002),
#   (6, 0.025000002),
#   (7, 0.025000002),
#   (8, 0.27499613),
#   (9, 0.52500004)],
#  [(0, 0.02),
#   (1, 0.02),
#   (2, 0.02),
#   (3, 0.02000717),
#   (4, 0.41999203),
#   (5, 0.02),
#   (6, 0.02),
#   (7, 0.02000058),
#   (8, 0.22000006),
#   (9, 0.22000015)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.05),
#   (9, 0.55)],
#  [(0, 0.050000004),
#   (1, 0.050000004),
#   (2, 0.050000004),
#   (3, 0.050000004),
#   (4, 0.050000004),
#   (5, 0.050000004),
#   (6, 0.55),
#   (7, 0.050000004),
#   (8, 0.050000004),
#   (9, 0.050000004)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.05),
#   (9, 0.55)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.033333335),
#   (1, 0.03333334),
#   (2, 0.033333335),
#   (3, 0.36674452),
#   (4, 0.033333335),
#   (5, 0.03333334),
#   (6, 0.033333335),
#   (7, 0.3665888),
#   (8, 0.033333335),
#   (9, 0.033333335)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.05),
#   (9, 0.55)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.05),
#   (9, 0.55)],
#  [(0, 0.025),
#   (1, 0.025),
#   (2, 0.025),
#   (3, 0.025),
#   (4, 0.025),
#   (5, 0.5249994),
#   (6, 0.025),
#   (7, 0.025),
#   (8, 0.025),
#   (9, 0.27500063)],
#  [(0, 0.033333335),
#   (1, 0.033333335),
#   (2, 0.033333335),
#   (3, 0.033333335),
#   (4, 0.033333335),
#   (5, 0.69999796),
#   (6, 0.033333335),
#   (7, 0.033335347),
#   (8, 0.033333335),
#   (9, 0.033333335)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.049999993),
#   (1, 0.049999993),
#   (2, 0.049999993),
#   (3, 0.049999993),
#   (4, 0.54999447),
#   (5, 0.049999993),
#   (6, 0.049999993),
#   (7, 0.050005525),
#   (8, 0.049999993),
#   (9, 0.049999993)],
#  [(0, 0.03333525),
#   (1, 0.033333335),
#   (2, 0.36666188),
#   (3, 0.033333335),
#   (4, 0.033333335),
#   (5, 0.033333335),
#   (6, 0.033338845),
#   (7, 0.36666405),
#   (8, 0.033333335),
#   (9, 0.033333335)],
#  [(0, 0.050003495),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.050001003),
#   (7, 0.5499955),
#   (8, 0.05),
#   (9, 0.05)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.5249738),
#   (1, 0.025000002),
#   (2, 0.2750241),
#   (3, 0.025000002),
#   (4, 0.025000002),
#   (5, 0.025000002),
#   (6, 0.025002085),
#   (7, 0.025000002),
#   (8, 0.025000002),
#   (9, 0.025000002)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.55),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.05),
#   (9, 0.05)],
#  [(0, 0.050000004),
#   (1, 0.050000004),
#   (2, 0.050000004),
#   (3, 0.050000004),
#   (4, 0.050000004),
#   (5, 0.050000004),
#   (6, 0.050000004),
#   (7, 0.55),
#   (8, 0.050000004),
#   (9, 0.050000004)],
#  [(0, 0.55),
#   (1, 0.050000004),
#   (2, 0.050000004),
#   (3, 0.050000004),
#   (4, 0.050000004),
#   (5, 0.050000004),
#   (6, 0.050000004),
#   (7, 0.050000004),
#   (8, 0.050000004),
#   (9, 0.050000004)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.025),
#   (1, 0.025),
#   (2, 0.025),
#   (3, 0.025),
#   (4, 0.025008352),
#   (5, 0.025),
#   (6, 0.025),
#   (7, 0.025),
#   (8, 0.7749765),
#   (9, 0.025015194)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.025),
#   (1, 0.025),
#   (2, 0.52500004),
#   (3, 0.025),
#   (4, 0.025),
#   (5, 0.27499253),
#   (6, 0.025),
#   (7, 0.025),
#   (8, 0.025),
#   (9, 0.025007414)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.016666668),
#   (1, 0.6833339),
#   (2, 0.016668908),
#   (3, 0.016666668),
#   (4, 0.016666668),
#   (5, 0.016666668),
#   (6, 0.016666668),
#   (7, 0.016666668),
#   (8, 0.016666668),
#   (9, 0.18333057)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.55),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.05),
#   (9, 0.05)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.033333335),
#   (1, 0.033333335),
#   (2, 0.033333335),
#   (3, 0.033333335),
#   (4, 0.033333335),
#   (5, 0.033333335),
#   (6, 0.36667466),
#   (7, 0.033333335),
#   (8, 0.033337947),
#   (9, 0.36665404)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.010000001),
#   (1, 0.3100039),
#   (2, 0.010000326),
#   (3, 0.010000161),
#   (4, 0.0100003015),
#   (5, 0.010000001),
#   (6, 0.30334896),
#   (7, 0.010000001),
#   (8, 0.010000925),
#   (9, 0.31664547)],
#  [(0, 0.033333335),
#   (1, 0.033333335),
#   (2, 0.033337895),
#   (3, 0.033333335),
#   (4, 0.033333335),
#   (5, 0.033333335),
#   (6, 0.033333335),
#   (7, 0.36666617),
#   (8, 0.033333335),
#   (9, 0.3666626)],
#  [(0, 0.02),
#   (1, 0.02),
#   (2, 0.61998713),
#   (3, 0.02),
#   (4, 0.02),
#   (5, 0.020002898),
#   (6, 0.02),
#   (7, 0.02),
#   (8, 0.22000912),
#   (9, 0.020000841)],
#  [(0, 0.016666668),
#   (1, 0.3500004),
#   (2, 0.25897193),
#   (3, 0.016666668),
#   (4, 0.016666668),
#   (5, 0.016666668),
#   (6, 0.27435312),
#   (7, 0.016666668),
#   (8, 0.016666668),
#   (9, 0.016674547)],
#  [(0, 0.014285715),
#   (1, 0.15715697),
#   (2, 0.014285715),
#   (3, 0.014287308),
#   (4, 0.15715894),
#   (5, 0.014285715),
#   (6, 0.014285715),
#   (7, 0.014287213),
#   (8, 0.58568096),
#   (9, 0.014285715)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.55),
#   (8, 0.05),
#   (9, 0.05)],
#  [(0, 0.011111111),
#   (1, 0.67777836),
#   (2, 0.011111111),
#   (3, 0.23333274),
#   (4, 0.011111111),
#   (5, 0.011111111),
#   (6, 0.011111111),
#   (7, 0.011111111),
#   (8, 0.011111111),
#   (9, 0.011111111)],
#  [(0, 0.033333335),
#   (1, 0.3666049),
#   (2, 0.033333335),
#   (3, 0.033333335),
#   (4, 0.033333335),
#   (5, 0.033333335),
#   (6, 0.033333335),
#   (7, 0.36672843),
#   (8, 0.033333335),
#   (9, 0.033333335)],
#  [(1, 0.43576595), (2, 0.078576155), (7, 0.24105461), (8, 0.20174447)],
#  [(0, 0.05),
#   (1, 0.05),
#   (2, 0.05),
#   (3, 0.05),
#   (4, 0.05),
#   (5, 0.05),
#   (6, 0.05),
#   (7, 0.05),
#   (8, 0.55),
#   (9, 0.05)],
#  [(1, 0.010001785),
#   (2, 0.010000175),
#   (3, 0.65959376),
#   (4, 0.010001348),
#   (5, 0.14999358),
#   (7, 0.12040862),
#   (9, 0.010000673)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.016667092),
#   (1, 0.016666666),
#   (2, 0.34999967),
#   (3, 0.18333349),
#   (4, 0.016668616),
#   (5, 0.016666787),
#   (6, 0.18332706),
#   (7, 0.016666666),
#   (8, 0.016670452),
#   (9, 0.18333346)],
#  [(0, 0.050000004),
#   (1, 0.050000004),
#   (2, 0.050000004),
#   (3, 0.050000004),
#   (4, 0.050000004),
#   (5, 0.050000004),
#   (6, 0.050000004),
#   (7, 0.55),
#   (8, 0.050000004),
#   (9, 0.050000004)],
#  [(0, 0.025001159),
#   (1, 0.025),
#   (2, 0.02500397),
#   (3, 0.025),
#   (4, 0.025),
#   (5, 0.025),
#   (6, 0.025007492),
#   (7, 0.5249987),
#   (8, 0.27498865),
#   (9, 0.025)],
#  [(0, 0.033333335),
#   (1, 0.033333335),
#   (2, 0.033333335),
#   (3, 0.033333335),
#   (4, 0.7),
#   (5, 0.033333335),
#   (6, 0.033333335),
#   (7, 0.033333335),
#   (8, 0.033333335),
#   (9, 0.033333335)],
#  [(0, 0.014285715),
#   (1, 0.014294595),
#   (2, 0.014292605),
#   (3, 0.014285715),
#   (4, 0.5187117),
#   (5, 0.014285715),
#   (6, 0.36698684),
#   (7, 0.014285715),
#   (8, 0.014285715),
#   (9, 0.014285715)],
#  [(0, 0.1),
#   (1, 0.1),
#   (2, 0.1),
#   (3, 0.1),
#   (4, 0.1),
#   (5, 0.1),
#   (6, 0.1),
#   (7, 0.1),
#   (8, 0.1),
#   (9, 0.1)],
#  [(0, 0.033333335),
#   (1, 0.033333335),
#   (2, 0.033333335),
#   (3, 0.7),
#   (4, 0.033333335),
#   (5, 0.033333335),
#   (6, 0.033333335),
#   (7, 0.033333335),
#   (8, 0.033333335),
#   (9, 0.033333335)]]

# %%
lda_feature = pd.read_excel('LDAFeatures.xlsx', sheet_name='final dataset')

print(lda_feature)
# Out:
#      Unnamed: 0         0         1  ...         7         8         9
# 0             0  0.100000  0.100000  ...  0.100000  0.100000  0.100000
# 1             1  0.100000  0.100000  ...  0.100000  0.100000  0.100000
# 2             2  0.050001  0.050001  ...  0.050001  0.050001  0.050001
# 3             3  0.033334  0.699991  ...  0.033334  0.033334  0.033336
# 4             4  0.774739  0.025029  ...  0.025029  0.025029  0.025029
# ..          ...       ...       ...  ...       ...       ...       ...
# 138         138  0.025005  0.025001  ...  0.025001  0.025000  0.025004
# 139         139  0.033395  0.367398  ...  0.033395  0.033395  0.033395
# 140         140  0.280397  0.014292  ...  0.014292  0.172274  0.014292
# 141         141  0.100000  0.100000  ...  0.100000  0.100000  0.100000
# 142         142  0.033336  0.033336  ...  0.033336  0.033336  0.366688
#
# [143 rows x 11 columns]

# %%
df = df.drop([0], axis=0)
df
df = df.drop([0], axis=1)
df

# %%
X = lda_feature
y = df["Label"]

# %%
X = X.iloc[:, 1:10]
X
# Out:
#             1         2         3  ...         7         8         9
# 0    0.100000  0.100000  0.100000  ...  0.100000  0.100000  0.100000
# 1    0.100000  0.100000  0.100000  ...  0.100000  0.100000  0.100000
# 2    0.050001  0.050001  0.549991  ...  0.050001  0.050001  0.050001
# 3    0.699991  0.033334  0.033334  ...  0.033334  0.033334  0.033336
# 4    0.025029  0.025029  0.025029  ...  0.025029  0.025029  0.025029
# ..        ...       ...       ...  ...       ...       ...       ...
# 138  0.025001  0.524990  0.025000  ...  0.025001  0.025000  0.025004
# 139  0.367398  0.033395  0.365444  ...  0.033395  0.033395  0.033395
# 140  0.014292  0.161455  0.300114  ...  0.014292  0.172274  0.014292
# 141  0.100000  0.100000  0.100000  ...  0.100000  0.100000  0.100000
# 142  0.033336  0.366625  0.033336  ...  0.033336  0.033336  0.366688
#
# [143 rows x 9 columns]

# %%
import pandas as pd
import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve, roc_auc_score
import sklearn.metrics as metrics
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.ensemble import RandomForestClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=1)

# %%
X_train
# Out:
#             1         2         3  ...         7         8         9
# 28   0.100000  0.100000  0.100000  ...  0.100000  0.100000  0.100000
# 101  0.100000  0.100000  0.100000  ...  0.100000  0.100000  0.100000
# 140  0.014292  0.161455  0.300114  ...  0.014292  0.172274  0.014292
# 124  0.033334  0.033334  0.033334  ...  0.033334  0.033334  0.033334
# 68   0.100000  0.100000  0.100000  ...  0.100000  0.100000  0.100000
# ..        ...       ...       ...  ...       ...       ...       ...
# 111  0.025002  0.025002  0.275018  ...  0.274969  0.025010  0.025002
# 110  0.100000  0.100000  0.100000  ...  0.100000  0.100000  0.100000
# 108  0.050000  0.050000  0.050000  ...  0.050000  0.050000  0.549999
# 129  0.050000  0.050000  0.050000  ...  0.050000  0.050000  0.549999
# 74   0.033363  0.033363  0.033363  ...  0.033363  0.033363  0.033363
#
# [102 rows x 9 columns]

# %%
# function to print out classification model report
def classification_report(model_name, test, pred):
    from sklearn.metrics import precision_score, recall_score
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    
    print(model_name, ":\n")
    print("Accuracy Score: ", '{:,.3f}'.format(float(accuracy_score(test, pred)) * 100), "%")
    print("     Precision: ", '{:,.3f}'.format(float(precision_score(test, pred, average='macro')) * 100), "%")
    print("        Recall: ", '{:,.3f}'.format(float(recall_score(test, pred, average='macro')) * 100), "%")
    print("      F1 score: ", '{:,.3f}'.format(float(f1_score(test, pred, average='macro')) * 100), "%")

# %%
rf = RandomForestClassifier(max_depth=1, random_state=0)
rf = rf.fit(X_train, y_train)
y_pred_train = rf.predict(X_train)
y_pred_val = rf.predict(X_val)
classification_report("Random forest Report (Training Set)", y_train, y_pred_train)
classification_report("Random forest Report (Validation Set)", y_val, y_pred_val)
# Out:
# Random forest Report (Training Set) :
#
# Accuracy Score:  73.529 %
#      Precision:  36.765 %
#         Recall:  50.000 %
#       F1 score:  42.373 %
# Random forest Report (Validation Set) :
#
# Accuracy Score:  58.333 %
#      Precision:  29.167 %
#         Recall:  50.000 %
#       F1 score:  36.842 %
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
rf = RandomForestClassifier(max_depth=2, random_state=0)
rf = rf.fit(X_train, y_train)
y_pred_train = rf.predict(X_train)
y_pred_val = rf.predict(X_val)
classification_report("Random forest Report (Training Set)", y_train, y_pred_train)
classification_report("Random forest Report (Validation Set)", y_val, y_pred_val)
# Out:
# Random forest Report (Training Set) :
#
# Accuracy Score:  78.431 %
#      Precision:  88.660 %
#         Recall:  59.259 %
#       F1 score:  59.230 %
# Random forest Report (Validation Set) :
#
# Accuracy Score:  58.333 %
#      Precision:  29.167 %
#         Recall:  50.000 %
#       F1 score:  36.842 %
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# MAX_depth =1 is chosen

# %%
rf = RandomForestClassifier(max_depth=1, random_state=0)
rf = rf.fit(X_test, y_test)
y_pred_test = rf.predict(X_test)
classification_report("Random forest Report (test Set)", y_test, y_pred_test)
# Out:
# Random forest Report (test Set) :
#
# Accuracy Score:  72.414 %
#      Precision:  36.207 %
#         Recall:  50.000 %
#       F1 score:  42.000 %
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# ### Visualizations

# %%
pip install pyLDAvis

# %%
import pyLDAvis
import pyLDAvis.gensim_models
lda_display = pyLDAvis.gensim_models.prepare(lda, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)

# %% [markdown]
# The code above from :
# https://towardsdatascience.com/topic-modelling-in-python-with-nltk-and-gensim-4ef03213cd21

# %% [markdown]
# The code above did not work! So I am trying another sample codes for LDA
# from
# https://www.kaggle.com/yashvi/topic-modelling-using-gensim-lda/notebook

# %% [markdown]
# ### Evaluation for our LDA method:

# %% [markdown]
# Though arbitrary, after running LDA, the data is now 'labeled'. We use the topics as labels. This means that we now use supervised learning to see how well the our topic modeling generalizes. This is just one way to evaluate the topic modeling. If the model was able to find a meaningful split in the data, it should be possible to train a classifier to predict which topic a given instance should belong to.

# %%
# function to print out classification model report
def classification_report(model_name, test, pred):
    from sklearn.metrics import precision_score, recall_score
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    
    print(model_name, ":\n")
    print("Accuracy Score: ", '{:,.3f}'.format(float(accuracy_score(test, pred)) * 100), "%")
    print("     Precision: ", '{:,.3f}'.format(float(precision_score(test, pred, average='macro')) * 100), "%")
    print("        Recall: ", '{:,.3f}'.format(float(recall_score(test, pred, average='macro')) * 100), "%")
    print("      F1 score: ", '{:,.3f}'.format(float(f1_score(test, pred, average='macro')) * 100), "%")

# %%
df_lda.iloc[:,15]

# %%
y_pred = df_lda.iloc[:,15]

# %%
from sklearn.model_selection import train_test_split

# test set size of 20% of the data and the random seed 42 <3
X_train, X_test, y_train, y_test = train_test_split(X_reduced ,y_pred, test_size=0.2, random_state=42)

print("X_train size:", len(X_train))
print("X_test size:", len(X_test), "\n")

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.linear_model import SGDClassifier

# SGD instance
sgd_clf = SGDClassifier(max_iter=10000, tol=1e-3, random_state=42, n_jobs=4)
# train SGD
sgd_clf.fit(X_train, y_train)

# cross validation predictions
sgd_pred = cross_val_predict(sgd_clf, X_train, y_train, cv=3, n_jobs=4)

# print out the classification report
classification_report("Stochastic Gradient Descent Report (Training Set)", y_train, sgd_pred)

# %% [markdown]
# **Emotions**
